# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# Simple data to display in various forms
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

plt.close('all')

train = pd.read_csv('../../data/mlbootcamp5_train.csv', sep=';',
                    index_col='id')

f, (ax1, ax2) = plt.subplots(2, sharex=True, sharey=False)


'''
from pylab import rcParams
rcParams['figure.figsize'] = 15, 10
ax1 = sns.heatmap(train.corr(method='pearson'), annot=True, fmt=".4f", linewidths=.5)
ax2 = sns.heatmap(train.corr(method='pearson'), annot=True, fmt=".4f", linewidths=.5)
'''

sns.boxplot(x='Churn', y='Total day minutes', data=df, ax=axes[0]);
sns.violinplot(x='Churn', y='Total day minutes', data=df, ax=axes[1]);

#ax1 = sns.heatmap(data=train.corr(method='pearson'), annot=True, fmt=".4f")
#men = train.loc[train.gender == 2]
#ax1 = sns.kdeplot(men.weight, men.height, cmap="Greens", cbar=True, shade=True, shade_lowest=False)
#women = train.loc[train.gender == 1]
#ax2 = sns.kdeplot(women.weight, women.height, cmap="Reds", cbar=True, shade=True, shade_lowest=False)
